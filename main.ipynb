# %%
import pandas as pd
import numpy as np
import nltk
from nltk.stem import WordNetLemmatizer
from nltk.stem import PorterStemmer
from nltk.corpus import stopwords
from nltk import FreqDist
from nltk.tokenize import sent_tokenize, word_tokenize
import PyPDF2
from PyPDF2 import PdfFileReader
import re 
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings("ignore")
#% matplotlib inline

# %%
def extract_pdf(pdf_path):
    party_pdf =  open(pdf_path, mode='rb')
    party = PyPDF2.PdfFileReader(party_pdf)
    pages = party.getNumPages()
    all_text=[]
    for i in range(pages):
        info=party.getPage(i)
        text=info.extractText()
        text_clean=re.sub('\n', '', text)
        all_text.append(text_clean)
    return all_text

# %% [markdown]
# from wordcloud import WordCloud
#
# unique_string=(" ").join(extract_pdf('podemos.pdf'))
# wordcloud = WordCloud(max_font_size=50, max_words=100, background_color="white", stopwords=None).generate(unique_string)
# plt.figure(figsize=(20,15))
#
# plt.imshow(wordcloud)
# plt.axis("off")
# plt.show()

# %%
def prepare_data(text):
    # Clean-Up
    text=re.sub(r"\d{1,}", "", text)
    text=re.sub(r'[-,.)(:%/;»«´˚]', "", text)
    text=re.sub("'", "", text)
    text=re.sub("˜", "fi", text)
    #text=re.sub("...", "", text)
    #text=re.sub(r'[^a-zA-Z-]', " ", text)
    # Tokenize
    text_token=word_tokenize(text.lower())

    # Stem and Lemmatize
    ps = PorterStemmer()
    lemmatizer = WordNetLemmatizer()
    text_stem=[]
    text_lem=[]
    for i in text_token:
        text_stem.append(ps.stem(i))
    for i in text_stem:
        text_lem.append(lemmatizer.lemmatize(i))


    # Remove Stopwords
    stopWords = set(stopwords.words('spanish'))          
    text_processed = []   
    for word in text_lem:
        if word not in stopWords:
            text_processed.append(word)

    return text_processed

# %%
# Getting most frequent words
def get_most_frequent(text):
    all_words=[]
    for word in text:
        all_words.append(word)
    freqDist = FreqDist(all_words).most_common(1000)
    most_frequent = [word[0] for word in freqDist]
    return most_frequent

# %%
podemos = extract_pdf('podemos.pdf')
podemos = prepare_data(str(podemos))
podemos = get_most_frequent(podemos)

ciudadanos = extract_pdf('ciudadanos.pdf')
ciudadanos = prepare_data(str(ciudadanos))
ciudadanos = get_most_frequent(ciudadanos)

pp = extract_pdf('pp.pdf')
pp = prepare_data(str(pp))
pp = get_most_frequent(pp)

psoe = extract_pdf('psoe.pdf')
psoe = prepare_data(str(psoe))
psoe = get_most_frequent(psoe)

vox = extract_pdf('vox.pdf')
vox = prepare_data(str(vox))
vox = get_most_frequent(vox)

# %%
podemos
# Out:
# ['derecho',
#  'má',
#  'persona',
#  'servicio',
#  'pública',
#  'sistema',
#  'est',
#  'público',
#  'paí',
#  'social',
#  'ley',
#  'manera',
#  'empresa',
#  'año',
#  'sector',
#  'españa',
#  'tiempo',
#  'sobr',
#  'empleo',
#  'toda',
#  'garantía',
#  'plan',
#  'mujer',
#  'así',
#  'impuesto',
#  'ello',
#  'acceso',
#  'justicia',
#  'grand',
#  'entr',
#  'meno',
#  'garantizar',
#  'solo',
#  'nuevo',
#  'caso',
#  'economía',
#  'mismo',
#  'objetivo',
#  'nueva',
#  'trabajo',
#  'familia',
#  'part',
#  'comunidad',
#  'euro',
#  'vivienda',
#  'medida',
#  'vida',
#  'actual',
#  'política',
#  'puedan',
#  'protección',
#  'modelo',
#  'situación',
#  'medio',
#  'centro',
#  'autónoma',
#  'horizont',
#  'europea',
#  'poder',
#  'travé',
#  'hacer',
#  'reforma',
#  'trabajador',
#  'seguridad',
#  'educación',
#  'fiscal',
#  'fin',
#  'trabajadora',
#  'cuidado',
#  'precio',
#  'sociedad',
#  'programa',
#  'mayor',
#  'calidad',
#  'proceso',
# ...

# %% [markdown]
# from wordcloud import WordCloud
#
# unique_string=(" ").join(podemos)
# wordcloud = WordCloud(max_font_size=50, max_words=100, background_color="white", stopwords=None).generate(unique_string)
# plt.figure(figsize=(20,15))
#
# plt.imshow(wordcloud)
# plt.axis("off")
# plt.show()

# %%
input_1='Quiero que haya mas igualdad en España y mas servicios sociales para los mas humildes, que los ricos paguen mas y los derechos sociales se respeten'
input_2='Viva España, viva la caza y los toros. Fuera los comunistas, que se respeten las tradiciones de este pais'

# %%
party_list=[podemos, psoe, ciudadanos,  pp, vox]

def jaccard_similarity(list1, list2):
    s1 = set(list1)
    s2 = set(list2)
    return len(s1.intersection(s2)) / len(s1.union(s2))

# %%
for i in party_list:
    print(jaccard_similarity(i, prepare_data(input_1)))
# Out:
# 0.004970178926441352
# 0.004970178926441352
# 0.013133208255159476
# 0.004970178926441352
# 0.005336179295624333

# %%
def jaccard_similarity2(list1, list2):
    intersection = len(list(set(list1).intersection(list2)))
    print(list(set(list1).intersection(list2)))
    union = (len(list1) + len(list2)) - intersection
    return float(intersection / union)

# %%
for i in party_list:
    print(jaccard_similarity2(i, prepare_data(input_1)))
# Out:
# ['derecho', 'servicio', 'social', 'españa', 'igualdad']
# 0.0049504950495049506
# ['derecho', 'servicio', 'social', 'españa', 'igualdad']
# 0.0049504950495049506
# ['derecho', 'servicio', 'españa', 'igualdad', 'respeten', 'paguen', 'social']
# 0.01303538175046555
# ['derecho', 'servicio', 'social', 'españa', 'igualdad']
# 0.0049504950495049506
# ['derecho', 'servicio', 'social', 'españa', 'igualdad']
# 0.005313496280552604

# %%
import re, math
from collections import Counter

WORD = re.compile(r'\w+')

def get_cosine(vec1, vec2):
    intersection = set(vec1.keys()) & set(vec2.keys())
    numerator = sum([vec1[x] * vec2[x] for x in intersection])

    sum1 = sum([vec1[x]**2 for x in vec1.keys()])
    sum2 = sum([vec2[x]**2 for x in vec2.keys()])
    denominator = math.sqrt(sum1) * math.sqrt(sum2)

     if not denominator:
        return 0.0
     else:
        return float(numerator) / denominator

def text_to_vector(text):
    words = WORD.findall(text)
    return Counter(words)

#text1 = 'Viva España, viva la caza y los toros. Fuera los comunistas, que se respeten las tradiciones de este pais'
text1='Quiero que haya mas igualdad en España y mas derechos y servicios sociales para las personas humildes, que los ricos paguen mas y los derechos sociales se respeten'

text2 = podemos

vector1 = text_to_vector(text1)
vector2 = text_to_vector(str(text2))

cosine = get_cosine(vector1, vector2)

cosine
# Out:
# 0.004552986372567942

# %%
# Use teo types of embeddings: Bag of Words and Word to Vec

# %%
stemmer = SnowballStemmer('english')
tokenizer = RegexpTokenizer(r'[a-zA-Z\']+')

# %%
import gensim

model = gensim.models.Word2Vec(podemos)

model.save('podemos.embedding')
new_model = gensim.models.Word2Vec.load('podemos.embedding')

# %%
new_model.most_similar(positive=['derecho'], topn = 3)

# %%
import spacy
spacy.load('es')

# %%
# Word token

from spacy.lang.es import Spanish
nlp = Spanish()
text = extract_pdf('podemos.pdf')
my_doc = nlp(str(text))
token_list = []
for token in my_doc:
    token_list.append(token.text)
print(token_list)
# Out:
# ['[', "'", 'PROGRAMA', 'DE', 'PODEMOS', 'para', 'un', 'nuevo', 'país', "'", ',', "''", ',', "'", 'ÍndicePrograma', 'para', 'un', 'nuevo', 'país', '...............................', '5Horizonte', 'Verde', 'y', 'Nuevo', 'Modelo', 'Industrial', '...................', '7Horizonte', 'Morado', 'y', 'Economía', 'de', 'los', 'Cuidados', '...............', '21Horizonte', 'Digital', 'y', 'Nueva', 'Economía', '.........................', '31Garantías', 'Democráticas', 'y', 'de', 'Ciudadanía', '.....................', '45Garantías', 'de', 'Justicia', 'Laboral', 'y', 'Pensiones', '....................', '63Garantías', 'de', 'Justicia', 'Social', '.................................', '77Garantías', 'de', 'Justicia', 'Fiscal', '.................................', '91Garantías', 'de', 'Justicia', 'Territorial', '..............................', '99', "'", ',', "''", ',', "'", 'PODEMOS.Programa', 'para', 'un', 'nuevo', 'paísEn', 'las', 'elecciones', 'del', '28', 'de', 'abril', 'hay', 'tres', 'opciones
# ...

# %%
# Sentence Token
nlp = Spanish()
sbd = nlp.create_pipe('sentencizer')
nlp.add_pipe(sbd)
text = extract_pdf('podemos.pdf')
doc = nlp(str(text))
sents_list = []
for sent in doc.sents:
    sents_list.append(sent.text)
print(sents_list)
# Out:
# ["['PROGRAMA DE PODEMOS para un nuevo país', '', 'ÍndicePrograma para un nuevo país ............................... 5Horizonte Verde y Nuevo Modelo Industrial ................... 7Horizonte Morado y Economía de los Cuidados ............... 21Horizonte Digital y Nueva Economía ......................... 31Garantías Democráticas y de Ciudadanía ..................... 45Garantías de Justicia Laboral y Pensiones .................... 63Garantías de Justicia Social ................................. 77Garantías de Justicia Fiscal ................................. 91Garantías de Justicia Territorial .............................. 99', '', 'PODEMOS.Programa para un nuevo paísEn las elecciones del 28 de abril hay tres opciones: cualquiera de los tres partidos de Aznar (PP, Ciudadanos y VOX, que son básicamente lo mismo), el PSOE o Unidas Podemos.", 'Los tres de Aznar quieren llevarnos cuarenta años al pasado en libertades civiles y derechos de las mujeres y comparten idénti-co programa económico
# ...

# %%
from spacy.lang.es.stop_words import STOP_WORDS
spacy_stopwords = spacy.lang.es.stop_words.STOP_WORDS

#Printing the total number of stop words:
print('Number of stop words: %d' % len(spacy_stopwords))

#Printing first ten stop words:
print('First ten stop words: %s' % list(spacy_stopwords)[:50])
# Out:
# Number of stop words: 551
# First ten stop words: ['aquella', 'da', 'haces', 'verdad', 'segun', 'dejó', 'vamos', 'considera', 'trabajar', 'ustedes', 'haciendo', 'antes', 'cierta', 'pocas', 'tres', 'mías', 'hasta', 'mia', 'pueden', 'tiempo', 'pero', 'estan', 'verdadero', 'ello', 'esta', 'esos', 'consigue', 'mismos', 'sido', 'eres', 'cuáles', 'ésas', 'mí', 'adelante', 'cuando', 'estaban', 'ambos', 'breve', 'siguiente', 'sin', 'nuestra', 'vuestros', 'nuestro', 'vez', 'quizá', 'misma', 'aquello', 'para', 'tú', 'una']

# %%
    # Remove Stopwords
    stopWords = set(stopwords.words('spanish'))          
    text_processed = []   
    for word in text_lem:
        if word not in stopWords:
            text_processed.append(word)

    return text_processed

# %%
filtered_sent=[]
doc = nlp(str(text))
for word in doc:
    if word.is_stop==False:
        filtered_sent.append(word)
print("Filtered Sentence:",filtered_sent)
# Out:
# Filtered Sentence: [[, ', PROGRAMA, DE, PODEMOS, país, ', ,, '', ,, ', ÍndicePrograma, país, ..............................., 5Horizonte, Verde, y, Nuevo, Modelo, Industrial, ..................., 7Horizonte, Morado, y, Economía, Cuidados, ..............., 21Horizonte, Digital, y, Nueva, Economía, ........................., 31Garantías, Democráticas, y, Ciudadanía, ....................., 45Garantías, Justicia, Laboral, y, Pensiones, ...................., 63Garantías, Justicia, Social, ................................., 77Garantías, Justicia, Fiscal, ................................., 91Garantías, Justicia, Territorial, .............................., 99, ', ,, '', ,, ', PODEMOS.Programa, paísEn, elecciones, 28, abril, opciones, :, cualquiera, partidos, Aznar, (, PP, ,, Ciudadanos, y, VOX, ,, básicamente, ), ,, PSOE, o, Unidas, Podemos, ., Los, Aznar, quieren, llevarnos, cuarenta, años, libertades, civiles, y, derechos, mujeres, y, comparten, idénti, -, co, programa, económico, :, aume
# ...

# %%
# Implementing lemmatization
lem = nlp(str(text))
# finding lemma for each word
for word in lem:
    print(word.text,word.lemma_)
# Out:
# [ [
# ' '
# PROGRAMA PROGRAMA
# DE DE
# PODEMOS PODEMOS
# para parir
# un uno
# nuevo nuevo
# país país
# ' '
# , ,
# '' ''
# , ,
# ' '
# ÍndicePrograma ÍndicePrograma
# para parir
# un uno
# nuevo nuevo
# país país
# ............................... ...............................
# 5Horizonte 5Horizonte
# Verde Verde
# y y
# Nuevo Nuevo
# Modelo Modelo
# Industrial Industrial
# ................... ...................
# 7Horizonte 7Horizonte
# Morado Morado
# y y
# Economía Economía
# de de
# los lo
# Cuidados Cuidados
# ............... ...............
# 21Horizonte 21Horizonte
# Digital Digital
# y y
# Nueva Nueva
# Economía Economía
# ......................... .........................
# 31Garantías 31Garantías
# Democráticas Democráticas
# y y
# de de
# Ciudadanía Ciudadanía
# ..................... .....................
# 45Garantías 45Garantías
# de de
# Justicia Justicia
# Laboral Laboral
# y y
# Pensiones Pensiones
# .................... ....................
# ...
